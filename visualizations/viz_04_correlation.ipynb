# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('C:/Users/Demoted/Downloads/datasci/Data_Science_FP')

df = pd.read_csv('Cleaned output data files/final_model_dataset.csv')

plt.figure(figsize=(14, 10))

correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', 
            center=0, square=True, linewidths=1, cbar_kws={"shrink": 0.8},
            vmin=-1, vmax=1)

plt.title('Feature Correlation Matrix\n(All Variables)', 
          fontsize=14, fontweight='bold', pad=20)
plt.xlabel('')
plt.ylabel('')

plt.tight_layout()

os.makedirs('visualizations/visualization_media', exist_ok=True)
plt.savefig('visualizations/visualization_media/viz_04_correlation_heatmap.png', dpi=300, bbox_inches='tight')

print("✓ Visualization 4 saved: visualizations/visualization_media/viz_04_correlation_heatmap.png")

plt.show()

print("\nTop correlations with LBW_Rate:")
lbw_corr = correlation_matrix['LBW_Rate'].sort_values(ascending=False)
print(lbw_corr)
# Out:
# ✓ Visualization 4 saved: visualizations/visualization_media/viz_04_correlation_heatmap.png
# Top correlations with LBW_Rate:
# LBW_Rate                          1.000000
# late_prenatal_care_prop           0.423077
# black_prop                        0.150944
# insurance_coverage_prop           0.106214
# maternal_age_risk_prop            0.056932
# Total_LBW_Count_2018_2022         0.006788
# low_education_prop               -0.002376
# ZIP_Code_of_Residence            -0.111556
# combined_noise_mean_db           -0.120574
# race_ethnicity_minority_status   -0.171394
# Total_Births_2018_2022           -0.337294
# Name: LBW_Rate, dtype: float64
