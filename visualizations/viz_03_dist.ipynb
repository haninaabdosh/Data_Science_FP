# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir('C:/Users/Demoted/Downloads/datasci/Data_Science_FP')

df = pd.read_csv('Cleaned output data files/final_model_dataset.csv')

plt.figure(figsize=(12, 7))

n, bins, patches = plt.hist(df['combined_noise_mean_db'], bins=20, color='#f59e0b', 
                             edgecolor='black', alpha=0.7, linewidth=1.2)

mean_noise = df['combined_noise_mean_db'].mean()
median_noise = df['combined_noise_mean_db'].median()
std_noise = df['combined_noise_mean_db'].std()

plt.axvline(mean_noise, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_noise:.2f} dB')
plt.axvline(median_noise, color='blue', linestyle='--', linewidth=2, label=f'Median: {median_noise:.2f} dB')

plt.xlabel('Combined Noise Level (dB)', fontsize=12, fontweight='bold')
plt.ylabel('Frequency (Number of ZIP Codes)', fontsize=12, fontweight='bold')
plt.title('Distribution of Prenatal Noise Exposure Across LA County ZIP Codes\n(2018-2022)', 
          fontsize=14, fontweight='bold', pad=20)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3, axis='y', linestyle='--')

textstr = f'n = {len(df)}\nStd Dev = {std_noise:.2f} dB\nRange: {df["combined_noise_mean_db"].min():.2f} - {df["combined_noise_mean_db"].max():.2f} dB'
plt.text(0.98, 0.97, textstr, transform=plt.gca().transAxes, fontsize=10,
         verticalalignment='top', horizontalalignment='right',
         bbox=dict(boxstyle='round', facecolor='lightcoral', alpha=0.8))

plt.tight_layout()

os.makedirs('visualizations/visualization_media', exist_ok=True)
plt.savefig('visualizations/visualization_media/viz_03_noise_distribution_histogram.png', dpi=300, bbox_inches='tight')

print("✓ Visualization 3 saved: visualizations/visualization_media/viz_03_noise_distribution_histogram.png")

plt.show()
# Out:
# ✓ Visualization 3 saved: visualizations/visualization_media/viz_03_noise_distribution_histogram.png
