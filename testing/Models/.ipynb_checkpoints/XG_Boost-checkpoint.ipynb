# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import xgboost as xgb

# %%
df = pd.read_csv(r"C:/Users/Elias/Final Project/EDA files/data_for_ml_final.csv")
df.shape, df.head()
# Out:
# ((222, 14),
#     ZIP_Code_of_Residence  LBW_Rate  Total_Births_2018_2022  \
#  0                  90001  7.825203                  3936.0
#  1                  90002  8.451621                  3839.5
#  2                  90003  7.871407                  5583.5
#  3                  90004  7.986374                  2642.0
#  4                  90005  9.108653                  1537.0
#
#     health_insurance_coverage_pop  income_distribution  \
#  0                          57639                13597
#  1                          53100                13013
#  2                          75006                17936
#  3                          58765                23047
#  4                          37655                16607
#
#     total_housing_population  total_race_population  \
#  0                     13597                  57652
#  1                     13013                  53108
#  2                     17936                  75024
# ...

# %%
TARGET = "LBW_Rate"
WEIGHT = "Total_Births_2018_2022"

FEATURES = [
    "health_insurance_coverage_pop",
    "income_distribution",
    "total_housing_population",
    "total_race_population",
    "total_ownership_population",
    "ses_pc1",
    "ses_cluster",
    "avg_traffic_pct",
    "health_insurance_coverage_pop_x_avg_traffic_pct",
    "income_distribution_x_avg_traffic_pct",
    "total_housing_population_x_avg_traffic_pct"
]

X = df[FEATURES]
y = df[TARGET]
weights = df[WEIGHT]

# %%
X_train, X_test, y_train, y_test, w_train, w_test = train_test_split(
    X, y, weights, test_size=0.2, random_state=42
)

model = xgb.XGBRegressor(
    n_estimators=500,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="reg:squarederror",
    random_state=42
)

model.fit(
    X_train,
    y_train,
    sample_weight=w_train,
    eval_set=[(X_test, y_test)],
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("XGBoost Regressor")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R²:   {r2:.4f}")
# Out:
# XGBoost Regressor
# RMSE: 1.2634
# MAE:  0.9648
# R²:   0.6590

# %%
xgb.plot_importance(model, max_num_features=10)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>
