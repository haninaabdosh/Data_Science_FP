# %%
import os
import pandas as pd

# Change to your project directory FIRST
os.chdir('C:/Users/Demoted/Downloads/datasci/Data_Science_FP')

# Verify you're in the right place
print(f"Current directory: {os.getcwd()}\n")

# Now load the CSV
df = pd.read_csv('Cleaned output data files/final_model_dataset.csv')

print("=" * 70)
print("COLUMN NAMES:")
print("=" * 70)
print(df.columns.tolist())

print("\n" + "=" * 70)
print("FIRST 5 ROWS:")
print("=" * 70)
print(df.head())

print("\n" + "=" * 70)
print("DATA SHAPE & INFO:")
print("=" * 70)
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
print(f"\nData types:\n{df.dtypes}")
# Out:
# Current directory: C:\Users\Demoted\Downloads\datasci\Data_Science_FP
#
# ======================================================================
# COLUMN NAMES:
# ======================================================================
# ['ZIP_Code_of_Residence', 'Total_Births_2018_2022', 'Total_LBW_Count_2018_2022', 'LBW_Rate', 'combined_noise_mean_db', 'race_ethnicity_minority_status', 'black_prop', 'insurance_coverage_prop', 'late_prenatal_care_prop', 'maternal_age_risk_prop', 'low_education_prop']
#
# ======================================================================
# FIRST 5 ROWS:
# ======================================================================
#    ZIP_Code_of_Residence  Total_Births_2018_2022  Total_LBW_Count_2018_2022  \
# 0                  90001                  3936.0                      308.0
# 1                  90002                  3839.5                      324.5
# 2                  90003                  5583.5                      439.5
# 3                  90004                  2642.0                      211.0
# 4                  90005                  1537.0                      140.0
#
#    LBW_Rate  combined_noise_mean_db  race_ethnicity_minority_status  \
# 0  7.825203               56.810581                          0.9909
# 1  8.451621               57.588403                          0.9926
# 2  7.871407               60.222628                          0.9921
# 3  7.986374               56.035845                          0.7972
# 4  9.108653               54.012587                          0.9054
#
#    black_prop  insurance_coverage_prop  late_prenatal_care_prop  \
# 0    0.074499                 0.999775                 0.188643
# 1    0.157321                 0.999849                 0.177367
# 2    0.164641                 0.999760                 0.198263
# 3    0.044516                 0.998844                 0.194739
# 4    0.053133                 0.997378                 0.165908
#
#    maternal_age_risk_prop  low_education_prop
# 0                0.178481            0.694106
# 1                0.169684            0.681339
# 2                0.170413            0.710844
# 3                0.331945            0.429220
# 4                0.292453            0.477554
#
# ======================================================================
# DATA SHAPE & INFO:
# ======================================================================
# Rows: 243, Columns: 11
#
# Data types:
# ZIP_Code_of_Residence               int64
# Total_Births_2018_2022            float64
# Total_LBW_Count_2018_2022         float64
# LBW_Rate                          float64
# combined_noise_mean_db            float64
# race_ethnicity_minority_status    float64
# black_prop                        float64
# insurance_coverage_prop           float64
# late_prenatal_care_prop           float64
# maternal_age_risk_prop            float64
# low_education_prop                float64
# dtype: object
